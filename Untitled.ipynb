# %%
#analysis of cars_db
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df = pd.read_csv('CarsData.csv')

# %%
df
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer
# ...

# %%
df.shape
# Out:
# (97712, 10)

# %%
df.head()
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0            I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1           Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2       2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3   Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4         Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
#
#    engineSize Manufacturer
# 0         1.0       hyundi
# 1         1.0   volkswagen
# 2         2.0          BMW
# 3         2.0        skoda
# 4         1.2         ford

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97712 entries, 0 to 97711
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         97712 non-null  object
#  1   year          97712 non-null  int64
#  2   price         97712 non-null  int64
#  3   transmission  97712 non-null  object
#  4   mileage       97712 non-null  int64
#  5   fuelType      97712 non-null  object
#  6   tax           97712 non-null  int64
#  7   mpg           97712 non-null  float64
#  8   engineSize    97712 non-null  float64
#  9   Manufacturer  97712 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 7.5+ MB

# %%
df.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798       Manual    10586   Diesel  150  48.7
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# dtype: int64

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  97712.000000   97712.000000   97712.000000  97712.000000  97712.000000
# mean    2017.066502   16773.487555   23219.475499    120.142408     55.205623
# std        2.118661    9868.552222   21060.882301     63.357250     16.181659
# min     1970.000000     450.000000       1.000000      0.000000      0.300000
# 25%     2016.000000    9999.000000    7673.000000    125.000000     47.100000
# 50%     2017.000000   14470.000000   17682.500000    145.000000     54.300000
# 75%     2019.000000   20750.000000   32500.000000    145.000000     62.800000
# max     2024.000000  159999.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  97712.000000
# mean       1.664913
# std        0.558574
# min        0.000000
# 25%        1.200000
# 50%        1.600000
# 75%        2.000000
# max        6.600000

# %%
df[['model']].describe
# Out:
# <bound method NDFrame.describe of                model
# 0                I10
# 1               Polo
# 2           2 Series
# 3       Yeti Outdoor
# 4             Fiesta
# ...              ...
# 97707         Fiesta
# 97708       3 Series
# 97709         Fiesta
# 97710          Astra
# 97711    Grandland X
#
# [97712 rows x 1 columns]>

# %%
ax=sns.countplot(x='year',data=df)
sns.set(rc={'figure.figsize':(25,5)})

# %%
bx=sns.countplot(x='transmission',data=df,hue='fuelType')
for bars in bx.containers:
    bx.bar_label(bars)

# %%
bx=sns.countplot(x='transmission',data=df,hue='fuelType').sum().sort_values(by='manufacturer')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 bx=sns.countplot(x='transmission',data=df,hue='fuelType').sum().sort_values(by='manufacturer')
#
# AttributeError: 'Axes' object has no attribute 'sum'

# %%
#sns.barplot(x='model',y='year',data=df).sort_values(by='year',ascending=False).head()
#sns.set(rc={'figure.figsize':(25,5)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sns.barplot(x='model',y='year',data=df).sort_values(by='year',ascending=False).head()
#       2 sns.set(rc={'figure.figsize':(25,5)})
#
# AttributeError: 'Axes' object has no attribute 'sort_values'

# %%
cx=sns.countplot(x='model',data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 cx=sns.countplot(x='model',data=df,hue='manufacturer')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# ...

# %%
df.model.mode()
# Out:
# 0     Fiesta
# Name: model, dtype: object

# %%
bmw=df.groupby('Manufacturer').sum().sort_values(by='model',ascending=True).head(3)

# %%
for x,y in bmw:
    print(x)
    print(y)
# Out:
# Audi
#       model  year  price transmission  mileage fuelType  tax   mpg  \
# 20       Q5  2020  37000    Semi-Auto     1000   Diesel  145  38.2
# 28       A4  2017  18182       Manual    18574   Petrol  145  51.4
# 41       A4  2020  29000    Semi-Auto       20   Petrol  145  42.2
# 57       Q3  2016  18505    Semi-Auto    31975   Diesel  160  50.4
# 74       Q3  2016  19950    Semi-Auto    25111   Diesel  145  51.4
# ...     ...   ...    ...          ...      ...      ...  ...   ...
# 97648    A3  2017  25990    Semi-Auto    25874   Petrol  150  43.5
# 97651    Q2  2017  19950       Manual    18315   Petrol  145  50.4
# 97694    A5  2019  31990    Automatic     1585   Petrol  145  37.2
# 97697    A1  2017  12700    Semi-Auto    10420   Petrol  150  64.2
# 97702    A4  2016  15000    Automatic    37004   Diesel   20  70.6
#
#        engineSize Manufacturer
# 20            2.0         Audi
# 28            1.4         Audi
# 41            2.0         Audi
# ...

# %%
bmw
# Out:
#                                                           model      year  \
# Manufacturer
# BMW            2 Series 1 Series 1 Series 1 Series X4 3 Seri...  21509958
# merc           A Class GLA Class C Class C Class GLC Class C...  25942066
# toyota         C-HR RAV4 Aygo Auris Yaris Yaris Yaris Yaris ...  13510160
#
#                   price                                       transmission  \
# Manufacturer
# BMW           241996965  Semi-AutoManualAutomaticManualAutomaticSemi-Au...
# merc          316824443  ManualAutomaticAutomaticAutomaticAutomaticSemi...
# toyota         83937124  AutomaticAutomaticManualManualManualManualAuto...
#
#                 mileage                                           fuelType  \
# Manufacturer
# BMW           274181880  DieselDieselPetrolDieselDieselDieselDieselPetr...
# merc          285100906  DieselDieselDieselDieselDieselDieselDieselHybr...
# toyota        153337355  HybridHybridPetrolPetrolPetrolPetrolHybridHybr...
#
# ...

# %%
#analysis-In 2019 Bmw series2,having Petrol engine and manual transmission had maximum number of sales as compare to others
